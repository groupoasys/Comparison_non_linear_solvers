# %%
import itertools
import numpy as np
import pickle
import pandas as pd
import datetime
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import os

# %%
path = r'C:\UMA\99 Pruebas_OASYS\Asun_prueba\results\Ouput_Model1'
u = pd.read_excel(os.path.join(path,'Output.xlsx'), 'u', index_col=0)

# %%
# %matplotlib notebook
plt.plot(u.index, u, marker='o', color='red', markerfacecolor='none')
# Out:
# <img src="data:image/png;base64,...">
